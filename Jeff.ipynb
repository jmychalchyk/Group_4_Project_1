# %%
import pandas as pd
import csv

fl = "data/train.csv"
df = pd.read_csv(fl)
df.head()
#drop bed_type, thumbnail, cleaning fee, name
#has thumbnail to TF

dfnew = df[["id",'amenities']]

# %%
dfnew.head()
# Out:
#          id                                          amenities
# 0   6901257  {"Wireless Internet","Air conditioning",Kitche...
# 1   6304928  {"Wireless Internet","Air conditioning",Kitche...
# 2   7919400  {TV,"Cable TV","Wireless Internet","Air condit...
# 3  13418779  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 4   3808709  {TV,Internet,"Wireless Internet","Air conditio...

# %%
# this converts the field   new=str(df['amenities'][0].replace('{',"").replace('}',"").replace('"','')).split(',')

# %%
#Creates a unique list of amenities
lst = []
for x in df["id"].index:
    newdf = str(df['amenities'][x].replace('{',"").replace('}',"").replace('"','')).split(',')
    for each in newdf:
        lst.append(each)
ds = pd.Series(lst).unique()

# %%
#Creates an empty dataframe to fill
index = df['id']
columns = ds
testdf = pd.DataFrame(index=index, columns=columns)
testdf = testdf.fillna(0) # with 0s rather than NaNs
testdf.head(5)
# Out:
#           Wireless Internet  Air conditioning  Kitchen  Heating  \
# id
# 6901257                   0                 0        0        0
# 6304928                   0                 0        0        0
# 7919400                   0                 0        0        0
# 13418779                  0                 0        0        0
# 3808709                   0                 0        0        0
#
#           Family/kid friendly  Essentials  Hair dryer  Iron  \
# id
# 6901257                     0           0           0     0
# 6304928                     0           0           0     0
# 7919400                     0           0           0     0
# 13418779                    0           0           0     0
# 3808709                     0           0           0     0
#
#           translation missing: en.hosting_amenity_50  Washer  \
# id
# 6901257                                            0       0
# 6304928                                            0       0
# ...

# %%
#populate the datafram with tic
#go though each testdf record and compare to df
for id in testdf.index:
    for id2 in df.index:
        df.loc[id==id2]
        for x in ds:
            for i in range(len(ds)):
                if ds[x] == testdf[i]:
                    testdf[i]=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-062ca10fb84a> in <module>()
#       3 for id in testdf.index:
#       4     for id2 in df.index:
# ----> 5         df.loc[id==id2]
#       6         for x in ds:
# ...
