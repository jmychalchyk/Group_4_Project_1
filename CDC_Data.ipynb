# %%
# Dependencies
import requests
from pprint import pprint
url = "https://data.cdc.gov/api/views/hmz2-vwda/rows.json?accessType=DOWNLOAD"
#api_key ='hjdrdtknrfsdixfg'

# Get information in JSON format
data = requests.get(url).json()
details = data["data"]
pprint(details[0])
# Out:
# [1,
#  'C26953B8-C007-4A5A-8875-BC975674CD34',
#  1,
#  1533066704,
#  '990162',
#  1533066704,
#  '990162',
#  None,
#  'UNITED STATES',
#  '2017',
#  'January',
#  'Monthly',
#  'Number of Live Births',
#  '314000']

# %%
for item in details:
    print(details[0])
# Out:
# [1, 'C26953B8-C007-4A5A-8875-BC975674CD34', 1, 1533066704, '990162', 1533066704, '990162', None, 'UNITED STATES', '2017', 'January', 'Monthly', 'Number of Live Births', '314000']
# [1, 'C26953B8-C007-4A5A-8875-BC975674CD34', 1, 1533066704, '990162', 1533066704, '990162', None, 'UNITED STATES', '2017', 'January', 'Monthly', 'Number of Live Births', '314000']
# [1, 'C26953B8-C007-4A5A-8875-BC975674CD34', 1, 1533066704, '990162', 1533066704, '990162', None, 'UNITED STATES', '2017', 'January', 'Monthly', 'Number of Live Births', '314000']
# [1, 'C26953B8-C007-4A5A-8875-BC975674CD34', 1, 1533066704, '990162', 1533066704, '990162', None, 'UNITED STATES', '2017', 'January', 'Monthly', 'Number of Live Births', '314000']
# [1, 'C26953B8-C007-4A5A-8875-BC975674CD34', 1, 1533066704, '990162', 1533066704, '990162', None, 'UNITED STATES', '2017', 'January', 'Monthly', 'Number of Live Births', '314000']
# ...
