# %%
import pandas as pd
import csv

fl = "data/train.csv"
df = pd.read_csv(fl)
df.head()
#drop bed_type, thumbnail, cleaning fee, name
#has thumbnail to TF
#df['neighbourhood'].unique()
# Out:
# array(['Brooklyn Heights', "Hell's Kitchen", 'Harlem', 'Lower Haight',
#        'Columbia Heights', 'Noe Valley', nan, 'Downtown',
#        'Richmond District', 'Alphabet City', 'Hermosa Beach', 'Torrance',
#        'U Street Corridor', 'Humboldt Park', 'Wicker Park',
#        'South Boston', 'Lower East Side', 'Flatbush', 'Sherman Oaks',
#        'East Flatbush', 'Valley Glen', 'Dupont Circle', 'Jamaica',
#        'Forest Hills', 'Murray Hill', 'Lefferts Garden', 'Mid-Wilshire',
#        'Venice', 'West Hollywood', 'Brownsville', 'Williamsburg',
#        'East Village', 'South Loop/Printers Row', 'Westlake',
#        'Hollywood Hills', 'Upper East Side', 'Bushwick',
#        'Bedford-Stuyvesant', 'Pilsen', 'Chelsea', 'Sunnyside',
#        'Greenwich Village', 'Washington Heights', 'Pasadena',
#        'Potrero Hill', 'Brookland', 'Los Feliz', 'Hollywood',
#        'Midtown East', 'Glendale', 'Park Slope', 'Arcadia',
# ...

# %%
df.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...    latitude   longitude  \
# 0  Real Bed              strict          True  ...   40.696524  -73.991617
# ...

# %%
lst=[]
new=str(df['amenities'][0].replace('{',"").replace('}',"").replace('"','')).split(',')
new
# Out:
# ['Wireless Internet',
#  'Air conditioning',
#  'Kitchen',
#  'Heating',
#  'Family/kid friendly',
#  'Essentials',
#  'Hair dryer',
#  'Iron',
#  'translation missing: en.hosting_amenity_50']

# %%
lst = []
for x in df["amenities"].index:
    newdf = str(df['amenities'][x].replace('{',"").replace('}',"").replace('"','')).split(',')
    for each in newdf:
        lst.append(each)
ds = pd.Series(lst).unique()

# %%
ds
# Out:
# array(['Wireless Internet', 'Air conditioning', 'Kitchen', 'Heating',
#        'Family/kid friendly', 'Essentials', 'Hair dryer', 'Iron',
#        'translation missing: en.hosting_amenity_50', 'Washer', 'Dryer',
#        'Smoke detector', 'Fire extinguisher', 'Shampoo', 'Hangers', 'TV',
#        'Cable TV', 'Breakfast', 'Buzzer/wireless intercom',
#        'Carbon monoxide detector', 'Laptop friendly workspace',
#        'Internet', 'Indoor fireplace', 'First aid kit',
#        'Elevator in building', 'Pool', 'Free parking on premises', 'Gym',
#        'Hot tub', 'Wheelchair accessible', 'Doorman', 'Dog(s)', 'Cat(s)',
#        'Other pet(s)', 'Lock on bedroom door',
#        'Pets live on this property', 'Private entrance', 'Hot water',
#        'Bed linens', 'Extra pillows and blankets', 'Coffee maker',
#        'Refrigerator', 'Dishes and silverware', 'Garden or backyard',
#        'Pets allowed', 'Safety card', '24-hour check-in', 'Self Check-In',
# ...

# %%
newdic = {}
lst = []
for x in df["amenities"].index:
    newdf = str(df['amenities'][x].replace('{',"").replace('}',"").replace('"','')).split(',')
    newdic[[["id"]=df["id"],
    'amenities':newdf]]
    for each in newdf:
        lst.append(each)
ds = pd.Series(lst).unique()
# Out:
#   File "<ipython-input-110-1038ca79bf1e>", line 5
#     newdic[[["id"]=df["id"],
#                   ^
# SyntaxError: invalid syntax
